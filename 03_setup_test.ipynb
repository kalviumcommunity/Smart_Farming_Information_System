# %%
x=18

# %%
print(x)
# Out:
# 18

# %%
import time

while True:
    print("Running...")
    time.sleep(1)
# Out:
# Running...
# Running...
# Running...
# Running...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 while True:
#       4     print("Running...")
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:
